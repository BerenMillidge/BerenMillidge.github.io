# %%
# quick investigation of integer tokenization in new model's tokenizers

import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

hf_auth_token = "<your_auth_token>"

#tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-Instruct-v0.2",use_auth_token = hf_auth_token, use_fast=False)

#tokenizer = AutoTokenizer.from_pretrained("google/gemma-7b",use_auth_token = hf_auth_token)

#tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b",use_auth_token = hf_auth_token)

#tokenizer = AutoTokenizer.from_pretrained("allenai/OLMo-1.7-7B",use_auth_token = hf_auth_token)

#tokenizer = AutoTokenizer.from_pretrained("meta-llama/Meta-Llama-3-8B",use_auth_token = hf_auth_token)

#tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-hf",use_auth_token = hf_auth_token)

#model_name = "deepseek-ai/deepseek-llm-7b-base"
#tokenizer = AutoTokenizer.from_pretrained(model_name)

#model_name = "deepseek-ai/DeepSeek-V2"
#tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)

#tokenizer = AutoTokenizer.from_pretrained("01-ai/Yi-34B", trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained("EleutherAI/pythia-1.4b", trust_remote_code=True)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
print(tokenizer)
# Out:
# LlamaTokenizerFast(name_or_path='meta-llama/Llama-2-7b-hf', vocab_size=32000, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>'}, clean_up_tokenization_spaces=False),  added_tokens_decoder={
# 	0: AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %%
for i in range(0,10000):
  toks = tokenizer.encode(str(i))
  print("SPLIT")
  for tok in toks:
    print(tokenizer.decode(tok))

# Summary:
# phi, mistral, llama2, gemma, yi, deepseek all use 1-2-3-4
# OAI https://platform.openai.com/tokenizer and Llama3 use a 3-n split. Unclear why.
# Out:
# Streaming output truncated to the last 5000 lines.
# SPLIT
# 6
# 363
# SPLIT
# 63
# 64
# SPLIT
# 6
# 365
# SPLIT
# 6
# 366
# SPLIT
# 6
# 367
# SPLIT
# 6
# 368
# SPLIT
# 6
# 369
# SPLIT
# 6
# 370
# SPLIT
# 6
# 371
# SPLIT
# 6
# 372
# SPLIT
# 6
# 373
# SPLIT
# 6
# 374
# SPLIT
# 6
# 375
# SPLIT
# 6
# 376
# SPLIT
# 6
# 377
# SPLIT
# 6
# 378
# SPLIT
# 6
# 379
# SPLIT
# 63
# 80
# SPLIT
# 6
# 381
# SPLIT
# 6
# 382
# SPLIT
# 6
# 383
# SPLIT
# 6
# 384
# SPLIT
# 6
# 385
# SPLIT
# 6
# 386
# SPLIT
# 6
# 387
# SPLIT
# 6
# 388
# SPLIT
# 6
# 389
# SPLIT
# 6
# 390
# SPLIT
# 6
# 391
# SPLIT
# 6
# 392
# SPLIT
# 6
# 393
# SPLIT
# 6
# 394
# SPLIT
# 6
# 395
# SPLIT
# 6
# 396
# SPLIT
# 6
# 397
# SPLIT
# 6
# 398
# SPLIT
# 63
# 99
# SPLIT
# 64
# 00
# SPLIT
# 64
# 01
# SPLIT
# 6
# 402
# SPLIT
# 6
# 403
# SPLIT
# 6
# 404
# SPLIT
# 6
# 405
# SPLIT
# 6
# 406
# SPLIT
# 6
# 407
# SPLIT
# 6
# 408
# SPLIT
# 6
# 409
# SPLIT
# 64
# 10
# SPLIT
# 64
# 11
# SPLIT
# 64
# 12
# SPLIT
# 64
# 13
# SPLIT
# 64
# 14
# SPLIT
# ...
